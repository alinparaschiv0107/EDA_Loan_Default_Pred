# %% [markdown]
# # Installs

# %%
pip install numerize
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for numerize: filename=numerize-0.12-py3-none-any.whl size=3156 sha256=396bba9cd8db03a6c3920e1637e7b83689ec6f4227c9eb1f16690a78816804ca
#   Stored in directory: /root/.cache/pip/wheels/87/84/e1/9e30f2e3da6590acb0f1c03a806e2673d2f9e7f5bd2b11589a
# Successfully built numerize
# ...

# %%
pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.5/540.5 kB 3.7 MB/s eta 0:00:00
# ...

# %%
pip install autoviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 787.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 38.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.3
#     Uninstalling xgboost-2.0.3:
#       Successfully uninstalled xgboost-2.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
# ...

# %%
pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 27.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, confusion_matrix, roc_curve
import numpy as np
import shap
from numerize import numerize
from autoviz.AutoViz_Class import AutoViz_Class
import sweetviz as sv
# Out:
# Imported v0.1.904. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Read DataFrame

# %%
data = pd.read_csv("/content/drive/MyDrive/DS Datasets/Loan_default.csv")
data.head()
# Out:
#      LoanID    Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96  56    85994     50587        520            80
# 1  HPSK72WA7R  69    50432    124440        458            15
# 2  C1OZ6DPJ8Y  46    84208    129188        451            26
# 3  V2KKSFM3UN  32    31713     44799        743             0
# 4  EY08JDHTZP  60    20437      9139        633             8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio  Education    \
# 0         4            15.23        36       0.44     Bachelor's
# 1         1             4.81        60       0.68       Master's
# 2         3            21.17        24       0.31       Master's
# 3         3             7.07        24       0.23    High School
# 4         4             6.51        48       0.73     Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0    Full-time      Divorced        Yes          Yes          Other
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## AutoViz

# %%
AV = AutoViz_Class()
# %matplotlib inline
#you have to specify the target variable
dft = AV.AutoViz(data, depVar = 'Default',max_rows_analyzed=len(data))
# Out:
# Shape of your Data Set loaded: (255347, 18)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  7
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     17 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['LoanID']
# ...

# %% [markdown]
# ## SweetViz

# %%
sweet_report = sv.analyze(data)
sweet_report.show_html('sweetviz_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Manual EDA

# %%
# drop ID column
data.drop(columns="LoanID",inplace=True)

# %%
# check for nulls
data.isnull().sum()
# Out:
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
# Categorical variables:
cat_cols = ["Default", "Education", "EmploymentType", "MaritalStatus",
            "HasMortgage", "HasDependents", "LoanPurpose", "HasCoSigner"]

sns.set_style("darkgrid")
fig,axes = plt.subplots(nrows = 4, ncols = 2, figsize = (10,11))
axes = axes.flat

for i,col in enumerate(cat_cols):
  sns.countplot(data,
               x = col,
               ax = axes[i])


  axes[i].set_xlabel("")
  axes[i].set_title(f"{col}", fontsize = 10, fontweight = "bold", color = "darkred")

  for rect in axes[i].patches:
    height = rect.get_height()
    axes[i].annotate(text = f'{numerize.numerize(height)}',
                xy = (rect.get_x()+rect.get_width()/2, height-20),
                xytext = (0,3),
                textcoords = 'offset points',
                ha = 'center',
                va = 'bottom',
                size = 8,
                weight = 'bold')


fig.suptitle("Distribution of categorical variables", fontsize = 12, fontweight = "bold", color = "darkblue")
fig.tight_layout()
fig.show()

# %%
num_cols = ["Age", "Income", "LoanAmount", "CreditScore", "MonthsEmployed",
            "NumCreditLines", "InterestRate", "LoanTerm", "DTIRatio"]

sns.set_style("darkgrid")
fig,axes = plt.subplots(nrows = 3, ncols = 3, figsize = (10,10))
axes = axes.flat

for i,col in enumerate(num_cols):
  sns.boxplot(data,
              x = "Default",
              y = col,
              ax = axes[i])

  axes[i].set_title(f"{col} by Default", fontsize = 10, fontweight = "bold")
  axes[i].set_xlabel("")

fig.suptitle("Distribution of quantitative variables according to the target variable(Default)",
             fontsize = 12, fontweight = "bold", color = "darkblue")
fig.tight_layout()
fig.show()

# %% [markdown]
# # Modeling

# %%
#indepent variables
X = data.drop(columns = ['Default'])

#target variable
y = data['Default']

# %%
categorical_columns = [col for col in X.columns if X[col].dtypes == 'object']

# %%
X = pd.get_dummies(X, columns = categorical_columns, drop_first = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
model = lgb.LGBMClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 23714, number of negative: 180563
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012456 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1315
# [LightGBM] [Info] Number of data points in the train set: 204277, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116087 -> initscore=-2.030014
# [LightGBM] [Info] Start training from score -2.030014
# LGBMClassifier()

# %%
y_predict = model.predict(X_test)

# %% [markdown]
# ## Accuracy

# %%
accuracy = accuracy_score(y_test, y_predict)
print('Accuracy for LGBM is', accuracy)
# Out:
# Accuracy for LGBM is 0.8865087135304484

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_predict)
fig, ax = plt.subplots(figsize = (8,6))
sns.heatmap(cm, annot = True, fmt = 'd')
plt.show()

# %% [markdown]
# ## Precision / Recall / AUC

# %%
precision = precision_score(y_test, y_predict)
recall = recall_score(y_test, y_predict)
print('Precision', precision)
print('Recall', recall)
# Out:
# Precision 0.6098310291858678
# Recall 0.06684627041589493

# %%
auc_score = roc_auc_score(y_test, y_predict)
print('AUC score', auc_score)
# Out:
# AUC score 0.5306091049405038

# %%
y_predict_probs = model.predict_proba(X_test)[:, 1]

# %%
auc_score = roc_auc_score(y_test, y_predict_probs)
print(auc_score)
# Out:
# 0.7513639598024286

# %% [markdown]
# ## Hyper-parameters tuning

# %%
n_estimators = [200, 250, 300, 350]
max_depths = [3, 4, 5]
learning_rates = [0.1, 0.05, 0.15]

# %%
results = []
for est in n_estimators:
    for md in max_depths:
        for lr in learning_rates:
            lgbm = lgb.LGBMClassifier(n_estimators = est,
                                  max_depth = md,
                                  learning_rate = lr,
                                  n_jobs = -1,
                                  random_state = 10,
                                  subsample = 0.6,
                                  colsample_bytree = 0.5,
                                  verbose=-1)
            lgbm.fit(X_train, y_train)
            y_predict_train = lgbm.predict_proba(X_train)[:,1]
            y_predict_test = lgbm.predict_proba(X_test)[:,1]
            auc_score_train = roc_auc_score(y_train, y_predict_train)
            auc_score_test = roc_auc_score(y_test, y_predict_test)
            results.append({"n_estimators":est,
                                      "max_depth":md,
                                      "learning_rate":lr,
                                      "train_auc_score":auc_score_train,
                                      "test_auc_score":auc_score_test,
                                      "auc_score_difference":auc_score_train-auc_score_test})
results_df = pd.DataFrame(results)

# %%
results_df.sort_values(by="test_auc_score",ascending=False).head(10)
# Out:
#     n_estimators  max_depth  learning_rate  train_auc_score  test_auc_score  \
# 31       350          4          0.05          0.770785         0.753109
# 22       300          4          0.05          0.769287         0.752929
# 13       250          4          0.05          0.767631         0.752839
# 3        200          4          0.10          0.771856         0.752777
# 28       350          3          0.05          0.763707         0.752764
# 18       300          3          0.10          0.766880         0.752764
# 11       250          3          0.15          0.768460         0.752750
# 12       250          4          0.10          0.774802         0.752744
# 9        250          3          0.10          0.765515         0.752730
# 27       350          3          0.10          0.767998         0.752718
#
#     auc_score_difference
# 31        0.017676
# 22        0.016358
# 13        0.014793
# 3         0.019080
# 28        0.010943
# 18        0.014117
# ...

# %%
model = lgb.LGBMClassifier(n_estimators = 350, max_depth = 4, learning_rate = 0.05, random_state=10,verbose=-1,
                            subsample = 0.6,
                            colsample_bytree = 0.5,
                            importance_type='gain')
model.fit(X_train, y_train)
# Out:
# LGBMClassifier(colsample_bytree=0.5, importance_type='gain', learning_rate=0.05,
#                max_depth=4, n_estimators=350, random_state=10, subsample=0.6,
#                verbose=-1)

# %%
y_predict_probs = model.predict_proba(X_test)[:, 1]

# %%
auc_score = roc_auc_score(y_test, y_predict_probs)
print(auc_score)
# Out:
# 0.753108573280241

# %% [markdown]
# # Lift & Gain Report

# %%
#declare an empty DataFrame
lift_gain_report = pd.DataFrame()

#add y_test in DataFrame
lift_gain_report['y_test'] = y_test

#### STEP 1 ####
# add predict probabilities for class 1 in DataFrame
lift_gain_report['Predicted Probabilities'] = y_predict_probs

# order probabilities in ascending order
lift_gain_report['Probabilities Rank'] = lift_gain_report['Predicted Probabilities'].rank(method = 'first', ascending = True, pct = True)

#### STEP 2 ####
#calculate decile group
lift_gain_report['Decile group'] = np.floor((1 - lift_gain_report['Probabilities Rank']) * 10) + 1

#### STEP 3 ####
#group observations by decile
lift_gain_report['Number of observations'] = 1
lift_gain_report = lift_gain_report.groupby(['Decile group']).sum().reset_index()

# cumulative number of observations
lift_gain_report['Cumulative no. of observations'] = lift_gain_report['Number of observations'].cumsum()

# cumulative percentage of observations
lift_gain_report['Cumulative % of no. of observations'] = lift_gain_report['Cumulative no. of observations'] / lift_gain_report['Cumulative no. of observations'].max()

#### STEP 4 ####
# calculate number of positives cumulative
lift_gain_report['Cumulative no. of positives'] = lift_gain_report['y_test'].cumsum()

#### STEP 5 ####
#calculate cumulative percentage of positives (Gain)
lift_gain_report['Gain'] = lift_gain_report['Cumulative no. of positives'] / lift_gain_report['Cumulative no. of positives'].max()

#### STEP 6 ####
# calculate Lift
lift_gain_report['Lift'] = lift_gain_report['Gain'] / lift_gain_report['Cumulative % of no. of observations']


lift_gain_report
# Out:
#    Decile group  y_test  Predicted Probabilities  Probabilities Rank  \
# 0       1.0       1859         1870.149770              4852.6
# 1       2.0       1081         1065.039031              4340.9
# 2       3.0        783          770.288419              3829.5
# 3       4.0        596          593.344638              3319.6
# 4       5.0        466          468.095852              2808.9
# 5       6.0        371          370.489801              2298.2
# 6       7.0        293          292.241260              1787.5
# 7       8.0        215          224.670878              1276.8
# 8       9.0        174          163.597468               766.1
# 9      10.0        101           95.555612               255.4
#
#    Number of observations  Cumulative no. of observations  \
# 0           5108                         5108
# 1           5107                        10215
# 2           5106                        15321
# 3           5107                        20428
# ...

# %%
fig, ax = plt.subplots(figsize = (15, 8))
barplot = plt.bar(lift_gain_report['Decile group'], lift_gain_report['Lift'])
plt.title('Lift bar plot')
plt.xlabel('Decile group')
plt.ylabel('Lift')
plt.xticks(lift_gain_report['Decile group'])

#add text above bars in chart
for b in barplot:
    plt.text(b.get_x() + b.get_width() / 2, b.get_height() + 0.1, round(b.get_height(), 2), ha = 'center')

plt.show()

# %%
lift_gain_report['Random Selection'] = lift_gain_report['Decile group'] / lift_gain_report['Decile group'].max()

# %%
fig, ax = plt.subplots(figsize = (12, 8))
sns.lineplot(data = lift_gain_report, x = lift_gain_report['Decile group'], y = lift_gain_report['Gain'])
sns.lineplot(data = lift_gain_report, x = lift_gain_report['Decile group'], y = lift_gain_report['Random Selection'])
plt.title('Gain plot')
plt.xticks(lift_gain_report['Decile group'])
plt.yticks(round(lift_gain_report['Gain'], 2))
plt.show()

# %% [markdown]
# # Feature Importance

# %%
gain_importance = model.feature_importances_
feature_names = X_train.columns
feature_importance = pd.DataFrame({'Feature': feature_names, 'Gain': gain_importance})

# %%
feature_importance['% Importance value'] = feature_importance['Gain'].values / feature_importance['Gain'].values.sum() * 100
feature_importance.sort_values(by = ['Gain'], ascending = False)
# Out:
#               Feature                 Gain      % Importance value
# 0                            Age  64099.925142       28.734797
# 6                   InterestRate  41638.781479       18.665886
# 1                         Income  36756.515837       16.477258
# 4                 MonthsEmployed  24937.302000       11.178926
# 2                     LoanAmount  24932.311170       11.176688
# 3                    CreditScore   5645.964861        2.530980
# 23               HasCoSigner_Yes   4023.679217        1.803740
# 14     EmploymentType_Unemployed   3003.857909        1.346573
# 18             HasDependents_Yes   2780.521799        1.246456
# 8                       DTIRatio   2648.302982        1.187185
# 5                 NumCreditLines   2544.360888        1.140589
# 15         MaritalStatus_Married   1919.914588        0.860662
# 17               HasMortgage_Yes   1322.985351        0.593070
# 21              LoanPurpose_Home   1320.789047        0.592085
# ...

# %% [markdown]
# # Feature Impact

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

# %%
shap.summary_plot(shap_values, X_test, plot_size = (20, 10))

# %%
index = 1200
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[index], X_test.iloc[index],link = 'logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...
